# %% [markdown]
# <a href="https://colab.research.google.com/github/KodumuruRaja/IMBalanced-Balanced-data/blob/main/Balanced-IMBalanced-Data1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
data.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
#                  ...
# MoSold           1460
# YrSold           1460
# SaleType         1460
# SaleCondition    1460
# SalePrice        1460
# Length: 81, dtype: int64

# %%
data1=data['MSZoning']

# %%
data1.unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
data1.nunique()
# Out:
# 5

# %%
data2=data[data['MSZoning']=='RL']

# %%
data2.count()
# Out:
# Id               1151
# MSSubClass       1151
# MSZoning         1151
# LotFrontage       922
# LotArea          1151
#                  ...
# MoSold           1151
# YrSold           1151
# SaleType         1151
# SaleCondition    1151
# SalePrice        1151
# Length: 81, dtype: int64

# %%
data2=data[data['MSZoning']=='RM']

# %%
data2.count()
# Out:
# Id               218
# MSSubClass       218
# MSZoning         218
# LotFrontage      199
# LotArea          218
#                 ...
# MoSold           218
# YrSold           218
# SaleType         218
# SaleCondition    218
# SalePrice        218
# Length: 81, dtype: int64

# %%
data2=data[data['MSZoning']=='C (all)']

# %%
data2.count()
# Out:
# Id               10
# MSSubClass       10
# MSZoning         10
# LotFrontage      10
# LotArea          10
#                  ..
# MoSold           10
# YrSold           10
# SaleType         10
# SaleCondition    10
# SalePrice        10
# Length: 81, dtype: int64

# %%
data2=data[data['MSZoning']=='FV']

# %%
data2.count()
# Out:
# Id               65
# MSSubClass       65
# MSZoning         65
# LotFrontage      57
# LotArea          65
#                  ..
# MoSold           65
# YrSold           65
# SaleType         65
# SaleCondition    65
# SalePrice        65
# Length: 81, dtype: int64

# %%
data2=data[data['MSZoning']=='RH']

# %%
data2.count()
# Out:
# Id               16
# MSSubClass       16
# MSZoning         16
# LotFrontage      13
# LotArea          16
#                  ..
# MoSold           16
# YrSold           16
# SaleType         16
# SaleCondition    16
# SalePrice        16
# Length: 81, dtype: int64

# %%
data['MSZoning'].count()
# Out:
# 1460

# %%
data['MSZoning'].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
data5=data[data.MSZoning!='FV']

# %%
data5.count()
# Out:
# Id               1395
# MSSubClass       1395
# MSZoning         1395
# LotFrontage      1144
# LotArea          1395
#                  ...
# MoSold           1395
# YrSold           1395
# SaleType         1395
# SaleCondition    1395
# SalePrice        1395
# Length: 81, dtype: int64

# %%
data6=data5.drop(data5[(data5['MSZoning']=='RH') | (data5['MSZoning']=='C (all)')].index)
data6
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1369 rows x 81 columns]

# %%
data6['MSZoning'].value_counts()
# Out:
# RL    1151
# RM     218
# Name: MSZoning, dtype: int64

# %%
pip install imbalanced-learn
